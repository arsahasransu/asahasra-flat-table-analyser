# %%
import ROOT
from IPython.display import Image

# %%
fMB = ROOT.TFile.Open('../OutHistoFiles/hists_MinBias.root')
hMB = fMB.Get('EB_TkEleL2_Pt5_EB_reisotot2026_dRmin0_03_puppiIsoDiff')
# hMBp = fMB.Get('EB_TkEleL2_Pt5_EB_reisotot_dRmin0_03_puppiIsoDiff')

c = ROOT.TCanvas('c1', 'c1', 800, 600)
ROOT.gStyle.SetOptStat(0)

print(hMB.GetBinContent(0), hMB.GetBinContent(hMB.GetNbinsX()//2),
      hMB.GetBinContent(hMB.GetNbinsX()//2+1), hMB.GetBinContent(hMB.GetNbinsX()+1))
hMB.Draw('hist e1')

# hMBp.SetLineWidth(0)
# hMBp.SetFillColorAlpha(ROOT.kPink+9, 0.5)
# hMBp.Draw('hist same e1')

c.SetLogy()
# Out:
# 31.0 13647521.0 336724.0 30.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_1780421788006" style="width: 800px; height: 600px; position: relative">
# </div>
# <script>
#    function process_root_plot_1780421788006() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(23884,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1780421788006', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
# ...

# %%
fMB = ROOT.TFile.Open('../OutHistoFiles/hists_MinBias.root')
hMB = fMB.Get('EB_TkEleL2_Pt5_EB_reisotot2026_dRmin0_03_puppiIsoDiff')
# hMBp = fMB.Get('EB_TkEleL2_Pt5_EB_reisotot_dRmin0_03_puppiIsoDiff')

c = ROOT.TCanvas('c1', 'c1', 800, 600)
ROOT.gStyle.SetOptStat(0)

print(hMB.GetBinContent(0), hMB.GetBinContent(hMB.GetNbinsX()//2),
      hMB.GetBinContent(hMB.GetNbinsX()//2+1), hMB.GetBinContent(hMB.GetNbinsX()+1))
hMB.Draw('hist e1')

# hMBp.SetLineWidth(0)
# hMBp.SetFillColorAlpha(ROOT.kPink+9, 0.5)
# hMBp.Draw('hist same e1')

c.SetLogy()
# Out:
# 26.0 13631651.0 330710.0 2896.0
# <div id="root_plot_1780421686783" style="width: 800px; height: 600px; position: relative">
# </div>
# <script>
#    function process_root_plot_1780421686783() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(29969,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1780421686783', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
# ...

# %%
fDYnoPU = ROOT.TFile.Open('../OutHistoFiles/hists_DY_noPU.root')
hDYnoPU = fDYnoPU.Get('GM_TkEleL2_EB_MCH_reisotot2026_dRmin0_03_puppiIsoDiff')
hDYnoPUp = fDYnoPU.Get('GM_TkEleL2_EB_MCH_reisotot_dRmin0_03_puppiIsoDiff')

c = ROOT.TCanvas('c1', 'c1', 800, 600)
ROOT.gStyle.SetOptStat(0)

print(hDYnoPU.GetBinContent(0), hDYnoPU.GetBinContent(hDYnoPU.GetNbinsX()//2),
      hDYnoPU.GetBinContent(hDYnoPU.GetNbinsX()//2+1), hDYnoPU.GetBinContent(hDYnoPU.GetNbinsX()+1))
hDYnoPU.Draw('hist e1')

hDYnoPUp.SetLineWidth(0)
hDYnoPUp.SetFillColorAlpha(ROOT.kPink+9, 0.5)
hDYnoPUp.Draw('hist same e1')

c.SetLogy()
# Out:
# 0.0 219916.0 14588.0 17.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
fDYPU200 = ROOT.TFile.Open('../OutHistoFiles/hists_DY_PU200.root')
hDYPU200 = fDYPU200.Get('GM_TkEleL2_EB_MCH_reisotot2026_dRmin0_03_puppiIsoDiff')
hDYPU200p = fDYPU200.Get('GM_TkEleL2_EB_MCH_reisotot_dRmin0_03_puppiIsoDiff')

c = ROOT.TCanvas('c1', 'c1', 800, 600)
ROOT.gStyle.SetOptStat(0)

hDYPU200.Draw('hist e1')

hDYPU200p.SetLineWidth(0)
hDYPU200p.SetFillColorAlpha(ROOT.kPink+9, 0.5)
hDYPU200p.Draw('hist same e1')

c.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
